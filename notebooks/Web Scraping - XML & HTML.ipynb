# %%
# install lxml using conda
# install beautifulsoup4 and html5lib using pip

# %%
import numpy as np
import pandas as pd

# %%
tables = pd.read_html('examples/fdic_failed_bank_list.html')

# %%
len(tables)
# Out:
# 1

# %%
failures = tables[0]

# %%
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
# compute the number of bank failures by year
close_timestamps = pd.to_datetime(failures['Closing Date'])

# %%
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# PARSING XML with lxml.objectify

# %%
# parse file and get a reference to the root node of XML using getroot
from lxml import objectify

# %%
path = 'datasets/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
# root.INDICATOR - parent
# getchildren() - scans tags in the INDICATOR root
# child.tag - select individual tag
# child.pyval - value of selected tag

data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
# convert list of dicts into DF

perf = pd.DataFrame(data)

perf.head()
# Out:
#             AGENCY_NAME            CATEGORY  \
# 0  Metro-North Railroad  Service Indicators
# 1  Metro-North Railroad  Service Indicators
# 2  Metro-North Railroad  Service Indicators
# 3  Metro-North Railroad  Service Indicators
# 4  Metro-North Railroad  Service Indicators
#
#                                          DESCRIPTION FREQUENCY  \
# 0  Percent of commuter trains that arrive at thei...         M
# 1  Percent of commuter trains that arrive at thei...         M
# 2  Percent of commuter trains that arrive at thei...         M
# 3  Percent of commuter trains that arrive at thei...         M
# 4  Percent of commuter trains that arrive at thei...         M
#
#                          INDICATOR_NAME INDICATOR_UNIT MONTHLY_ACTUAL  \
# 0  On-Time Performance (West of Hudson)              %           96.9
# 1  On-Time Performance (West of Hudson)              %             95
# 2  On-Time Performance (West of Hudson)              %           96.9
# 3  On-Time Performance (West of Hudson)              %           98.3
# 4  On-Time Performance (West of Hudson)              %           95.8
#
#   MONTHLY_TARGET  PERIOD_MONTH  PERIOD_YEAR YTD_ACTUAL YTD_TARGET
# 0             95             1         2008       96.9         95
# 1             95             2         2008         96         95
# 2             95             3         2008       96.3         95
# 3             95             4         2008       96.8         95
# 4             95             5         2008       96.6         95

# %%
# extract tag's metadata from HTML snippet
from io import StringIO

# %%
tag = '<a href="https://www.google.com">Google</a>'
tag2 = '<h1>This is Python for Data Science</h1>'
root = objectify.parse(StringIO(tag)).getroot()
root2 = objectify.parse(StringIO(tag2)).getroot()

# %%
root
# Out:
# <Element a at 0x108424f08>

# %%
root.get('href')
# Out:
# 'https://www.google.com'

# %%
root.text
# Out:
# 'Google'

# %%
root2
# Out:
# <Element h1 at 0x1060d5648>

# %%
root2.text
# Out:
# 'This is Python for Data Science'

# %% [markdown]
# BINARY DATA FORMATS

# %%
# writing data into pickle format
frame = pd.read_csv('examples/ex1.csv')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame.to_pickle('examples/frame_pickle')

# %%
pd.read_pickle('examples/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# USING HDF5 FORMAT

# %%
# can store large quantities of scientific data
# available as a C library with interfaces to other languages
# HDF5 - hierarchical data format
# supports on fly compression with modes
# HDFStore class - works like a dictionary able to handle low-level details

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})

store = pd.HDFStore('mydata.h5')

store['obj1'] = frame

store['obj1_col'] = frame['a']

store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1'].head()
# Out:
#           a
# 0 -0.119035
# 1 -0.948321
# 2 -0.460960
# 3  0.101210
# 4  1.240919

# %%
# HDFStore - storage schemas - 'fixed' and 'table'
# table is slower but supports query ops
store.put('obj2', frame, format='table')

store.select('obj2', where=['index >= 10 and index <= 15'])
# Out:
#            a
# 10  0.138589
# 11 -0.389294
# 12 -1.883468
# 13  0.498393
# 14  0.181005
# 15 -1.009128

# %%
store.close()

# %%
# shortcut - pandas.read_hdf
frame.to_hdf('mydata.h5', 'obj3', format='table')

pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])
# Out:
#           a
# 0 -0.119035
# 1 -0.948321
# 2 -0.460960
# 3  0.101210
# 4  1.240919

# %% [markdown]
# READING EXCEL FILES

# %%
# using ExcelFile
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# useful to define multiple sheets at a time
pd.read_excel(xlsx, 'Sheet1')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# can pass filename to pandas.read_excel
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# write pandas data to Excel format - create ExcelWriter
writer = pd.ExcelWriter('examples/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()

# %%
# can pass a file path to to_excel and avoid ExcelWriter
frame.to_excel('examples/ex2.xlsx')

# %%
# read new file
new_file = pd.read_excel('examples/ex2.xlsx', 'Sheet1')
new_file
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# INTERACTING WITH WEB APIs

# %%
# websites have public APIs - feeds - JSON format
# find last 30 GitHub issues for pandas, make a GET HTTP request
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
# response object's json method will return a dictionary
# with JSON parsed into native Python objects

# %%
for x in data:
    for key in x:
        print(key)
# Out:
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# pull_request
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# body

# %%
data = resp.json()

print("User: ", data[0]['user']['login'])
print("Title: ", data[0]['title'])
# Out:
# User:  diogo-bastos
# Title:  DOC: Fix quotes position in Timestamp and Timedelta

# %%
# passing data in DF and extract fields of interest
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues.head()
# Out:
#    number                                              title  \
# 0   24243  DOC: Fix quotes position in Timestamp and Time...
# 1   24242  TST: Hypothesis may draw a date outside of dat...
# 2   24241  Series.apply on categorical with NaN has wrong...
# 3   24240  DOC: Fix flake8 issues in doc/source/whatsnew/...
# 4   24239   DOC: Fix flake8 issues in doc/source/whatsnew...
#
#                                               labels state
# 0                                                 []  open
# 1                                                 []  open
# 2                                                 []  open
# 3  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 4  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open

# %%
# another example
user_details = pd.DataFrame(data, columns=["user", 'title'])
user_details.head()
# Out:
#                                                 user  \
# 0  {'login': 'diogo-bastos', 'id': 11160226, 'nod...
# 1  {'login': 'topper-123', 'id': 26364415, 'node_...
# 2  {'login': 'tchklovski', 'id': 278558, 'node_id...
# 3  {'login': 'saurav2608', 'id': 4477229, 'node_i...
# 4  {'login': 'saurav2608', 'id': 4477229, 'node_i...
#
#                                                title
# 0  DOC: Fix quotes position in Timestamp and Time...
# 1  TST: Hypothesis may draw a date outside of dat...
# 2  Series.apply on categorical with NaN has wrong...
# 3  DOC: Fix flake8 issues in doc/source/whatsnew/...
# 4   DOC: Fix flake8 issues in doc/source/whatsnew...

# %% [markdown]
# INTERACTING WITH DATABASES

# %%
# creating SQLite db using sqlite3 driver
import sqlite3

# %%
query = "CREATE TABLE test (a VARCHAR(20), b VARCHAR(20), c REAL, d INTEGER);"

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
# insert new data
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()

# %%
# selection of data returns a list of tuples
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
# passing list of tuples to DF constructor
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
# using SQLAlchemy to read data from above DF
import sqlalchemy as sqla

# %%
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
